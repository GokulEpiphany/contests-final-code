# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks import *

# %%
torch.cuda.is_available()
# Out:
# True

# %%
np.random.seed(42)

# %%
tfms = rand_resize_crop(768,max_scale=1.5,ratios=(0.75, 2))

# %%
mixup=0.2

# %%
loss_func = LabelSmoothingCrossEntropy()

# %%
# class FocalLoss(nn.Module):
#     def __init__(self, alpha=1., gamma=1.):
#         super().__init__()
#         self.alpha = alpha
#         self.gamma = gamma

#     def forward(self, inputs, targets, **kwargs):
#         CE_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
#         pt = torch.exp(-CE_loss)
#         F_loss = self.alpha * ((1-pt)**self.gamma) * CE_loss
#         return F_loss.mean()
# loss_func = FocalLoss(gamma=3.)

# %%
alpha=0.99
mom=0.9
eps=1e-6

# %%
opt_func = partial(optim.Adam, betas=(mom,alpha), eps=eps)

# %%
src = (ImageList.from_folder(path='train').split_by_rand_pct(0.2).label_from_folder())

# %%
data = src.transform((tfms),size=(768)).databunch(bs=16).normalize()

# %%
data.show_batch(3,figsize=(15,9))

# %%
learn = cnn_learner(data, models.densenet121,pretrained=False, metrics=[error_rate, accuracy, FBeta(beta=1,average='macro')],loss_func = loss_func,opt_func=opt_func,wd=1e-2)
# Out:
# /home/ubuntu/anaconda3/envs/snakes_breed/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
learn= learn.mixup(alpha=mixup)

# %%
learn.bn_wd=False

# %%
learn.true_wd=True

# %%
learn.load('exp-11-round-3')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (65934 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: CategoryList
# class-857,class-857,class-857,class-857,class-857
# Path: train;
#
# Valid: LabelList (16483 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: CategoryList
# class-540,class-526,class-771,class-4,class-804
# Path: train;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
# ...

# %%
learn = learn.to_fp16(dynamic=True)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit(10,slice(1e-6,5e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.756396</td>
#       <td>1.374050</td>
#       <td>0.228053</td>
#       <td>0.771947</td>
#       <td>0.730144</td>
#       <td>31:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.810880</td>
#       <td>1.356773</td>
#       <td>0.222836</td>
#       <td>0.777164</td>
#       <td>0.735526</td>
#       <td>31:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.787353</td>
#       <td>1.374031</td>
#       <td>0.225444</td>
#       <td>0.774556</td>
#       <td>0.730515</td>
#       <td>31:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.750650</td>
#       <td>1.355060</td>
#       <td>0.222957</td>
# ...

# %%
learn.validate()
# Out:
# [1.3553582, tensor(0.2201), tensor(0.7799), tensor(0.7397)]

# %%
learn.save('exp-11-round-4')

# %%
learn.fit_one_cycle(5,slice(1e-7,1e-6))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 31:31<2:06:07]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
learn.save('exp-11-round-5')
